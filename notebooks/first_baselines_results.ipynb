# %% [markdown]
# # Simple similarity search

# %% [markdown]
# ## Data reading

# %%
import pandas as pd

data = pd.read_csv('../data/RAW_recipes.csv')
data.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# The data was cleaned with following pipeline:
# ```py
# def clean_text(text):
#     # Convert text to lowercase
#     text = text.lower()
#
#     # Remove punctuation
#     text = text.translate(str.maketrans('', '', string.punctuation))
#
#     # Tokenize the text
#     tokens = text.split()
#
#     # Remove stopwords
#     stop_words = set(stopwords.words('english'))
#     tokens = [word for word in tokens if word not in stop_words]
#
#     # Lemmatize the tokens
#     lemmatizer = WordNetLemmatizer()
#     tokens = [lemmatizer.lemmatize(word) for word in tokens]
#
#     # Join the tokens back into a single string
#     cleaned_text = ' '.join(tokens)
#
#     return cleaned_text
# ```

# %% [markdown]
# ## First query

# %% [markdown]
# query: chicken with creamy sauce
# result:

# %% [markdown]
# ### TFIDF + FAISS

# %%
results = [43291, 44435, 81669, 184585, 62393, 98489, 62915, 46373, 62733, 61581]
data.loc[results]
# Out:
#                                                 name      id  minutes  \
# 43291                      chicken breast  hot spicy   18607       30
# 44435                    chicken in creamy pan sauce  287625       30
# 81669   fajita salad with creamy cilantro lime sauce  115346       30
# 184585                 sharon s creamy chile chicken  187102       25
# 62393                   creamy buffalo chicken pasta  229231       35
# 98489                        grilled chicken alfredo  503258       30
# 62915                           creamy curry chicken  252894       31
# 46373          chicken with creamy green onion sauce  291657       20
# 62733                    creamy chipotle chili sauce  217439       30
# 61581                             cream cheese sauce  181346       20
#
#         contributor_id   submitted  \
# 43291            30139  2002-01-31
# 44435           333250  2008-02-22
# 81669            97825  2005-04-05
# 184585          165623  2006-09-20
# 62393           487279  2007-05-21
# 98489          2891694  2013-07-06
# 62915           587294  2007-09-13
# 46373           644191  2008-03-13
# 62733           104018  2007-03-18
# 61581           341170  2006-08-10
#
#                                                      tags  \
# 43291   ['30-minutes-or-less', 'time-to-make', 'course...
# 44435   ['30-minutes-or-less', 'time-to-make', 'course...
# 81669   ['30-minutes-or-less', 'time-to-make', 'course...
# 184585  ['30-minutes-or-less', 'time-to-make', 'course...
# 62393   ['60-minutes-or-less', 'time-to-make', 'main-i...
# 98489   ['30-minutes-or-less', 'time-to-make', 'main-i...
# 62915   ['curries', '60-minutes-or-less', 'time-to-mak...
# 46373   ['30-minutes-or-less', 'time-to-make', 'course...
# 62733   ['30-minutes-or-less', 'time-to-make', 'course...
# 61581   ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                           nutrition  n_steps  \
# 43291     [442.2, 46.0, 8.0, 75.0, 68.0, 67.0, 2.0]        8
# 44435     [276.0, 23.0, 0.0, 12.0, 59.0, 35.0, 1.0]       18
# 81669   [531.3, 29.0, 36.0, 34.0, 83.0, 19.0, 16.0]       12
# 184585    [413.4, 33.0, 7.0, 29.0, 68.0, 61.0, 6.0]       10
# 62393     [385.2, 43.0, 9.0, 18.0, 52.0, 33.0, 2.0]        9
# 98489   [770.6, 39.0, 17.0, 28.0, 93.0, 51.0, 29.0]        6
# 62915    [417.7, 48.0, 19.0, 20.0, 46.0, 85.0, 3.0]       21
# 46373    [513.8, 47.0, 13.0, 23.0, 98.0, 63.0, 2.0]       10
# 62733        [92.0, 12.0, 6.0, 5.0, 1.0, 11.0, 1.0]        2
# 61581       [137.2, 20.0, 3.0, 5.0, 4.0, 39.0, 0.0]        4
#
#                                                     steps  \
# 43291   ['squeeze the lime juice into a bowl , add hot...
# 44435   ['place chicken inside a resealable plastic ba...
# 81669   ['combine all ingredients for cilantro-lime sa...
# 184585  ['cook chicken in butter', 'set aside , keepin...
# 62393   ['cut chicken breast into bite-size pieces and...
# 98489   ['marinate chicken in italian dressing for at ...
# 62915   ['directions:', 'for the chicken marinade , mi...
# 46373   ['melt butter over med', 'high heat', 'stir in...
# 62733   ['mix all of the ingredients in a small bowl',...
# 61581   ['melt together cream cheese and butter in a s...
#
#                                               description  \
# 43291                                      chicken breast
# 44435   i got this recipe from kraft foods magazine an...
# 81669    great for summer salad recipe from cooking light
# 184585   this is just dreamy creamy ... thanks sharon g!!
# 62393   your chicken, your hotness and your bleu chees...
# 98489   grilled chicken on top of a bed of fettuchini ...
# 62915   creamy curry sauce with chicken breast pieces....
# 46373   this creamy, smooth and tangy sauce is a hit i...
# 62733                         creamy chipotle chili sauce
# 61581   a warm creamy sauce that's perfect over pasta ...
#
#                                               ingredients  n_ingredients
# 43291   ['chicken breasts', 'hot sauce', 'mustard', 'b...              7
# 44435   ['boneless skinless chicken breast', 'flour', ...              7
# 81669   ['olive oil', 'ground cumin', 'paprika', 'chil...             22
# 184585  ['boneless skinless chicken breasts', 'butter'...              9
# 62393   ['chicken breast', 'paprika', 'garlic powder',...             10
# 98489   ['cream cheese', 'milk', 'ground pepper', 'gar...              9
# 62915   ['boneless skinless chicken breast half', 'yog...             17
# 46373   ['chicken breasts', 'butter', 'all-purpose flo...              9
# 62733   ['mayonnaise', 'sour cream', 'chipotle chiles ...              6
# 61581        ['cream cheese', 'butter', 'milk', 'garlic']              4

# %% [markdown]
# ### BM25

# %%
results_bm25 = [46373, 78734, 76112, 62393]
data.loc[results_bm25]
# Out:
#                                           name      id  minutes  \
# 46373    chicken with creamy green onion sauce  291657       20
# 78734  easy  yummy  creamy  chicken tetrazzini  469300       30
# 76112                easy creamy lemon chicken  124344       20
# 62393             creamy buffalo chicken pasta  229231       35
#
#        contributor_id   submitted  \
# 46373          644191  2008-03-13
# 78734         1726293  2011-12-01
# 76112          219874  2005-06-01
# 62393          487279  2007-05-21
#
#                                                     tags  \
# 46373  ['30-minutes-or-less', 'time-to-make', 'course...
# 78734  ['30-minutes-or-less', 'time-to-make', 'course...
# 76112  ['30-minutes-or-less', 'time-to-make', 'course...
# 62393  ['60-minutes-or-less', 'time-to-make', 'main-i...
#
#                                         nutrition  n_steps  \
# 46373  [513.8, 47.0, 13.0, 23.0, 98.0, 63.0, 2.0]       10
# 78734   [351.2, 27.0, 6.0, 31.0, 47.0, 34.0, 7.0]        9
# 76112  [398.6, 17.0, 4.0, 47.0, 116.0, 15.0, 4.0]        5
# 62393   [385.2, 43.0, 9.0, 18.0, 52.0, 33.0, 2.0]        9
#
#                                                    steps  \
# 46373  ['melt butter over med', 'high heat', 'stir in...
# 78734  ['cook noodles as directed on box', 'partially...
# 76112  ['cook chicken breasts on grill', "if you don'...
# 62393  ['cut chicken breast into bite-size pieces and...
#
#                                              description  \
# 46373  this creamy, smooth and tangy sauce is a hit i...
# 78734                            easy, creamy and yummy!
# 76112  a variation of the campbell's soup creamy lemo...
# 62393  your chicken, your hotness and your bleu chees...
#
#                                              ingredients  n_ingredients
# 46373  ['chicken breasts', 'butter', 'all-purpose flo...              9
# 78734  ['cream of mushroom soup', 'chicken breasts', ...              7
# 76112  ['boneless skinless chicken breasts', 'cream o...              5
# 62393  ['chicken breast', 'paprika', 'garlic powder',...             10

# %% [markdown]
# ## Second query
#
# query: poultry meat in mediterranean style
# (pol: drób w stylu śródziemnomorskim)

# %%
""" 
Results:
                                                     name      id  ...  n_ingredients                                           combined
161580                                      please ignore  409347  ...              2      please ignore construction please ignore none
116548  kariokor nyama ya kuchoma  barbecued meat rub ...  307071  ...              7  kariokor nyama ya kuchoma barbecued meat rub k...
77685                        easy pot roast   asian style   58794  ...              8  easy pot roast asian style mom used make dish ...
190335                       smothered nutria cajun style  418543  ...              8  smothered nutria cajun style nutria also calle...
223958  waldorf style chicken saladwaldorf style chick...   24924  ...              7  waldorf style chicken saladwaldorf style chick...
74198                dzik  yucatecan style salpicn de res  248709  ...             14  dzik yucatecan style salpicn de re incredibly ...
20776               beef style seasoning or chicken style  486189  ...              9  beef style seasoning chicken style asked recip...
163451                                        pork madras  205317  ...             14  pork madras fairly simple tasty version indian...
230024                                    yummy meat cake  415408  ...              7  yummy meat cake meat cake combined meatloaf st...
162876                pork barbecue  north carolina style  174305  ...             11  pork barbecue north carolina style pork barbec..."""

results_tfidf = [161580, 116548, 77685, 190335, 223958, 74198, 20776, 163451, 230024, 162876]
data.loc[results_tfidf]
# Out:
#                                                      name      id  minutes  \
# 161580                                      please ignore  409347        7
# 116548  kariokor nyama ya kuchoma  barbecued meat rub ...  307071        5
# 77685                        easy pot roast   asian style   58794      225
# 190335                       smothered nutria cajun style  418543       60
# 223958  waldorf style chicken saladwaldorf style chick...   24924       70
# 74198                dzik  yucatecan style salpicn de res  248709      140
# 20776               beef style seasoning or chicken style  486189        5
# 163451                                        pork madras  205317      150
# 230024                                    yummy meat cake  415408       55
# 162876                pork barbecue  north carolina style  174305      390
#
#         contributor_id   submitted  \
# 161580           35635  2010-01-19
# 116548          461834  2008-06-03
# 77685            59307  2003-04-08
# 190335           64642  2010-03-30
# 223958            6164  2002-04-11
# 74198           128945  2007-08-25
# 20776            37449  2012-08-30
# 163451          330621  2007-01-14
# 230024          524700  2010-03-04
# 162876          289066  2006-06-21
#
#                                                      tags  \
# 161580  ['15-minutes-or-less', 'time-to-make', 'course...
# 116548  ['15-minutes-or-less', 'time-to-make', 'course...
# 77685   ['weeknight', 'time-to-make', 'course', 'main-...
# 190335  ['weeknight', '60-minutes-or-less', 'time-to-m...
# 223958  ['weeknight', 'time-to-make', 'course', 'main-...
# 74198   ['time-to-make', 'course', 'main-ingredient', ...
# 20776   ['15-minutes-or-less', 'time-to-make', 'prepar...
# 163451  ['curries', 'time-to-make', 'course', 'main-in...
# 230024  ['60-minutes-or-less', 'time-to-make', 'course...
# 162876  ['course', 'main-ingredient', 'cuisine', 'nort...
#
#                                             nutrition  n_steps  \
# 161580          [73.5, 7.0, 1.0, 2.0, 12.0, 7.0, 0.0]        1
# 116548    [161.1, 1.0, 105.0, 2358.0, 5.0, 1.0, 13.0]        2
# 77685    [932.0, 109.0, 2.0, 28.0, 127.0, 132.0, 1.0]        9
# 190335      [187.7, 14.0, 31.0, 13.0, 14.0, 8.0, 6.0]        7
# 223958          [69.5, 5.0, 28.0, 1.0, 2.0, 1.0, 3.0]        3
# 74198      [576.2, 52.0, 20.0, 6.0, 103.0, 50.0, 5.0]       12
# 20776   [1126.6, 39.0, 6.0, 299.0, 267.0, 16.0, 50.0]        3
# 163451   [844.0, 104.0, 33.0, 20.0, 86.0, 174.0, 5.0]       11
# 230024     [622.8, 57.0, 7.0, 45.0, 56.0, 47.0, 14.0]        5
# 162876     [566.7, 56.0, 44.0, 32.0, 82.0, 62.0, 5.0]       12
#
#                                                     steps  \
# 161580                                           ['none']
# 116548  ['thoroughly combine all ingredients', 'rub on...
# 77685   ['season meat with a little soy sauce and garl...
# 190335  ['heat oil in stockpot until very hot', 'sprin...
# 223958  ['mix together all ingredients', 'cover and re...
# 74198   ['the meat: bring 3 cups water to a boil in a ...
# 20776   ['mix all together and keep in a jar with a ti...
# 163451  ['mix together all the spices and add a few sp...
# 230024  ['mix flour & baking powder in a bowl', 'add o...
# 162876  ['put roast in roasting pan', 'combine remaini...
#
#                                               description  \
# 161580                  under construction, please ignore
# 116548  barbecued meat, nairobi market style (kenya)\r...
# 77685   my mom used to make this dish all the time. it...
# 190335  the nutria (also called ragondin) is a fur bea...
# 223958                       mix, refrigerate and eat...!
# 74198   this is incredibly delicious and very authenti...
# 20776   i was asked for a recipe for beef style season...
# 163451  a fairly simple and tasty version of the india...
# 230024                meat & cake combined meatloaf style
# 162876                pork barbecue, north carolina style
#
#                                               ingredients  n_ingredients
# 161580                                   ['egg', 'water']              2
# 116548  ['coarse salt', 'coarse black pepper', 'crushe...              7
# 77685   ['pot roast', 'oil', 'soy sauce', 'garlic powd...              8
# 190335  ['vegetable oil', 'nutria', 'cajun seasoning',...              8
# 223958  ['chicken', 'mayonnaise', 'apple', 'raisins', ...              7
# 74198   ['flank steaks', 'garlic clove', 'bay leaves',...             14
# 20776   ['nutritional yeast', 'onion powder', 'salt', ...              9
# 163451  ['country-style pork ribs', 'chili powder', 'g...             14
# 230024  ['ground beef', 'egg', 'onion soup mix', 'oil'...              7
# 162876  ['boston butt', 'onion', 'water', 'vinegar', '...             11
